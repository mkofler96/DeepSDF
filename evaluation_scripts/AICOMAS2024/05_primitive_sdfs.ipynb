# %%
from sdf_sampler.sdf_sampler import BoxSDF, SphereSDF, Blend, CrossSDF
from sdf_sampler.plotting import scatter_contour_at_origin
import matplotlib.pyplot as plt

sphere = SphereSDF(0.7)
cross = CrossSDF(0.4)
fig1 = scatter_contour_at_origin(sphere)
fig2 = scatter_contour_at_origin(cross)
blend_cross = Blend(sphere, cross, 0.2)
fig3 = scatter_contour_at_origin(blend_cross)
fig1.savefig("evaluation_scripts/AICOMAS2024/plots/circle_sdf", bbox_inches="tight")
fig2.savefig("evaluation_scripts/AICOMAS2024/plots/cross_sdf", bbox_inches="tight")
fig3.savefig("evaluation_scripts/AICOMAS2024/plots/merge_circle_cross_sdf", bbox_inches="tight")

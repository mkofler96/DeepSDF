# %%
from optimization.opti import struct_optimization
import os 
os.chdir("/home/michael.kofler/DeepSDF")
optimization = struct_optimization("optimization_runs/round_cross_more_knot_vecs_limit")
import matplotlib.pyplot as plt
plt.style.use("evaluation_scripts/paper/science.mplstyle")

plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
})
cm_to_inch = 1/2.54
fig, ax = plt.subplots()
optimization.plot_convergence(custom_axis=ax)
ax.set_ylabel("Normalized Value")
ax.set_xlim(0, 40)
fig.savefig("evaluation_scripts/paper/screenshots/objective_and_constraint_limits.png", bbox_inches="tight", dpi=600)
# Out:
# OptimizationResults(compliance=[0.00035868864416377605, 0.00026998307471145887, 0.0002215762933545071, 0.00019262804955270886, 0.00017405194252879613, 0.00016028431708406735, 0.0001555473743261078, 0.00015178090741053561, 0.0001488599952923157, 0.0001461459673150976, 0.00014418593394703008, 0.00014148984817076855, 0.000139216524364868, 0.0001374467539153462, 0.00013485266280765203, 0.00013351943849703143, 0.00013227766106152776, 0.00013176593467340928, 0.00013134825538019867, 0.00013082725719232565, 0.00013001657393305565, 0.00012925350000817453, 0.00012869900217701564, 0.0001280504937234595, 0.000127222323868662, 0.00012647577541673765, 0.0001258469227722308, 0.00012500415520323835, 0.00012490820029844053, 0.00012382916855624757, 0.00012371450385069205, 0.00012339550296877353, 0.00012299580308113662, 0.00012287069203615223, 0.00012252728231488928, 0.00012220720462581173, 0.00012212144003984123, 0.00012194507661867709, 0.0001217242946377694, 0.00012140446887341624, 0.0001212885316896
# ...

# %%
optimization = struct_optimization("optimization_runs/round_cross_more_knot_vecs")
import matplotlib.pyplot as plt
plt.style.use("evaluation_scripts/paper/science.mplstyle")

plt.rcParams.update({
    'text.usetex': True,
    'font.family': 'serif',
})
cm_to_inch = 1/2.54
fig, ax = plt.subplots()
optimization.plot_convergence(custom_axis=ax)
ax.set_ylabel("Normalized Value")
ax.set_xlim(0, 80)
fig.savefig("evaluation_scripts/paper/screenshots/objective_and_constraint_no_limits.png", bbox_inches="tight", dpi=600)
# Out:
# OptimizationResults(compliance=[0.00019794488277237037, 0.00019287955809705996, 0.00018322711291461993, 0.00017278913344369684, 0.00016405179524072846, 0.00015794413507435074, 0.00015303419635714362, 0.00014900566341664517, 0.0001459558542377704, 0.00014348901814660288, 0.0001411196770723867, 0.00013820411088975306, 0.00013585496720567027, 0.00013274894306173127, 0.00012952509091602218, 0.00012738519309628358, 0.00012460241279525238, 0.0001210919979500451, 0.00011905484251074435, 0.00011549184733492656, 0.00011304779020274673, 0.0001112871015866261, 0.00011096644483522015, 0.00010816599252346276, 0.00010626097485614491, 0.00010477374598426559, 0.00010362581542896732, 0.00010264477861813088, 0.00010177976696593544, 0.00010109930598538426, 0.0001003327810966896, 9.943074690873689e-05, 9.898496463933216e-05, 9.876975960555953e-05, 9.865113683145048e-05, 9.820477806431758e-05, 9.771266473449125e-05, 9.717692366796085e-05, 9.721643397024796e-05, 9.694141543445545e-05, 9.692072011835144e-0
# ...
